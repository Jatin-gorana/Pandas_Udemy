# %%
import pandas as pd

# %%
data = pd.read_csv('sample.csv')

# %%
data.head(10)
# Out:
#    quarter      SER_REF industry_code                        industry_name  \
# 0  2020.09  BDCQ.SEA1AA             A    Agriculture, Forestry and Fishing
# 1  2020.09  BDCQ.SEA1BA             B                               Mining
# 2  2020.09  BDCQ.SEA1CA             C                        Manufacturing
# 3  2020.09  BDCQ.SEA1DA             D  Electricity, Gas, Water and Waste S
# 4  2020.09  BDCQ.SEA1EA             E                         Construction
# 5  2020.09  BDCQ.SEA1FA             F                      Wholesale Trade
# 6  2020.09  BDCQ.SEA1GA             G                         Retail Trade
# 7  2020.09  BDCQ.SEA1HA             H      Accommodation and Food Services
# 8  2020.09  BDCQ.SEA1IA             I    Transport, Postal and Warehousing
# 9  2020.09  BDCQ.SEA1JA             J  Information Media and Telecommunica
#
#    filled jobs  filled jobs revised  filled jobs diff  filled jobs % diff  \
# ...

# %%
# import psycopg2 as pg2      #this is used for postgresql linkup but for now its not downloaded

# %%
data.columns
# Out:
# Index(['quarter', 'SER_REF', 'industry_code', 'industry_name', 'filled jobs',
#        'filled jobs revised', 'filled jobs diff', 'filled jobs % diff',
#        'total_earnings', 'total earnings revised', 'earnings diff',
#        'earnings % diff'],
#       dtype='object')

# %%
df1 = data[['SER_REF', 'industry_code', 'industry_name', 'filled jobs']]

# %%
df1
# Out:
#          SER_REF industry_code                        industry_name  \
# 0    BDCQ.SEA1AA             A    Agriculture, Forestry and Fishing
# 1    BDCQ.SEA1BA             B                               Mining
# 2    BDCQ.SEA1CA             C                        Manufacturing
# 3    BDCQ.SEA1DA             D  Electricity, Gas, Water and Waste S
# 4    BDCQ.SEA1EA             E                         Construction
# ..           ...           ...                                  ...
# 195  BDCQ.SEA1PA             P               Education and Training
# 196  BDCQ.SEA1QA             Q    Health Care and Social Assistance
# 197  BDCQ.SEA1RA             R         Arts and Recreation Services
# 198  BDCQ.SEA1SA             S                       Other Services
# 199  BDCQ.SEA1ZA             Z                       Total Industry
#
#      filled jobs
# 0          93195
# 1           5340
# 2         217139
# 3          19886
# 4         166413
# ..           ...
# 195       200765
# ...

# %%
data.tail()
# Out:
#      quarter      SER_REF industry_code                      industry_name  \
# 195  2022.12  BDCQ.SEA1PA             P             Education and Training
# 196  2022.12  BDCQ.SEA1QA             Q  Health Care and Social Assistance
# 197  2022.12  BDCQ.SEA1RA             R       Arts and Recreation Services
# 198  2022.12  BDCQ.SEA1SA             S                     Other Services
# 199  2022.12  BDCQ.SEA1ZA             Z                     Total Industry
#
#      filled jobs  filled jobs revised  filled jobs diff  filled jobs % diff  \
# 195       200765               202179              1414                 0.7
# 196       254497               257381              2884                 1.1
# 197        40102                40417               315                 0.8
# 198        73051                73296               245                 0.3
# 199      2233837              2256452             22615                 1.0
#
# ...

# %%
display(data.iloc[6])
# Out:
# quarter                        2020.09
# SER_REF                    BDCQ.SEA1GA
# industry_code                        G
# industry_name             Retail Trade
# filled jobs                     197373
# filled jobs revised             198379
# filled jobs diff                  1006
# filled jobs % diff                 0.5
# total_earnings                    2160
# total earnings revised            2173
# earnings diff                       13
# earnings % diff                    0.6
# Name: 6, dtype: object

# %%
data.rank()
# Out:
#      quarter  SER_REF  industry_code  industry_name  filled jobs  \
# 0       10.5      5.5            5.5           25.5         86.0
# 1       10.5     15.5           15.5          115.5          2.0
# 2       10.5     25.5           25.5          105.5        171.0
# 3       10.5     35.5           35.5           65.5         11.0
# 4       10.5     45.5           45.5           45.5        135.0
# ..       ...      ...            ...            ...          ...
# 195    190.5    155.5          155.5           55.5        164.0
# 196    190.5    165.5          165.5           85.5        188.0
# 197    190.5    175.5          175.5           35.5         49.0
# 198    190.5    185.5          185.5          125.5         70.0
# 199    190.5    195.5          195.5          175.5        200.0
#
#      filled jobs revised  filled jobs diff  filled jobs % diff  \
# 0                   85.0              63.0                42.5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   quarter                 200 non-null    float64
#  1   SER_REF                 200 non-null    object
#  2   industry_code           200 non-null    object
#  3   industry_name           200 non-null    object
#  4   filled jobs             200 non-null    int64
#  5   filled jobs revised     200 non-null    int64
#  6   filled jobs diff        200 non-null    int64
#  7   filled jobs % diff      200 non-null    float64
#  8   total_earnings          200 non-null    int64
#  9   total earnings revised  200 non-null    int64
#  10  earnings diff           200 non-null    int64
#  11  earnings % diff         200 non-null    float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 18.9+ KB

# %%
import webbrowser

# %%
website = 'https://pandas.org/pandas-docs/refernce/api/pandas.DataFrame.html'
# website = 'https://www.google.com/'

# %%
webbrowser.open(website)
# webbrowser.open_new_tab(website)
# webbrowser.open('https://www.google.com/')
# Out:
# True

# %%
df2 = data.sample(10)

# %%
df2
# Out:
#      quarter      SER_REF industry_code                        industry_name  \
# 81   2021.09  BDCQ.SEA1BA             B                               Mining
# 56   2021.03  BDCQ.SEA1QA             Q    Health Care and Social Assistance
# 65   2021.06  BDCQ.SEA1FA             F                      Wholesale Trade
# 22   2020.12  BDCQ.SEA1CA             C                        Manufacturing
# 135  2022.03  BDCQ.SEA1PA             P               Education and Training
# 19   2020.09  BDCQ.SEA1ZA             Z                       Total Industry
# 42   2021.03  BDCQ.SEA1CA             C                        Manufacturing
# 11   2020.09  BDCQ.SEA1LA             L  Rental, Hiring and Real Estate Serv
# 121  2022.03  BDCQ.SEA1BA             B                               Mining
# 50   2021.03  BDCQ.SEA1KA             K     Financial and Insurance Services
#
#      filled jobs  filled jobs revised  filled jobs diff  filled jobs % diff  \
# ...

# %%
# Now visualisation starts
# We are starting to make charts using matplotlib

# %%
data.columns
# Out:
# Index(['quarter', 'SER_REF', 'industry_code', 'industry_name', 'filled jobs',
#        'filled jobs revised', 'filled jobs diff', 'filled jobs % diff',
#        'total_earnings', 'total earnings revised', 'earnings diff',
#        'earnings % diff'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
ic = data['industry_code']
te = data['total_earnings']
plt.bar(ic, te)
plt.ylabel('total_earnings')
plt.xlabel('industry_code')
plt.show()

# %%
data.describe()
# Out:
#           quarter   filled jobs  filled jobs revised  filled jobs diff  \
# count   200.00000  2.000000e+02         2.000000e+02        200.000000
# mean   2021.28100  2.156726e+05         2.177362e+05       2063.600000
# std       0.74124  4.521149e+05         4.564216e+05       4410.620442
# min    2020.09000  5.271000e+03         5.295000e+03       -161.000000
# 25%    2021.03000  5.544250e+04         5.624525e+04        404.250000
# 50%    2021.10500  1.033985e+05         1.049300e+05        987.500000
# 75%    2022.06000  1.870135e+05         1.887132e+05       1703.750000
# max    2022.12000  2.233837e+06         2.256452e+06      28071.000000
#
#        filled jobs % diff  total_earnings  total earnings revised  \
# count          200.000000      200.000000              200.000000
# mean             1.028500     3653.040000             3690.325000
# std              0.746474     7684.498263             7762.590183
# ...
